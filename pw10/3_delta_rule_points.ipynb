# %% [markdown]
# # Delta Rule
# The Delta Rule is a gradient descent approximator that can be used to find the weight values of a Perceptron. The Delta Rule minimizes an error function (tipically $E=\frac{1}{2}(y - t)^{2}$) by adapting the weight connections in small steps. The step length is defined by the learning rate $\alpha$. In this notebook you will explore the classification capabilities of a single Perceptron by using the delta rule. You will start by setting the connection weights by hand for a simple problem, and then you will apply the delta rule for the same problem, and others.

# %% [markdown]
# ## Loading the packages

# %%
import numpy as np
from ipywidgets import interact, widgets

from matplotlib import animation

# %% [markdown]
# ## Loading the Perceptron code
# In order to the make this nothebook smaller, some of the functions (activation functions, and some of the code allowing the visualization of the results) was implemented in a separate python file. You are free to open it if needed.

# %%
import perceptron as pt

# %% [markdown]
# ## The Dataset
# The following script allows you to create a 2D dataset by using the mouse. First click to add points belonging to class A (blue), and then click to add points belonging to class B (red). You can create as many points as you desire. The final dataset will contain hence three values per point: x coordinate (-1 ≤ x ≤ 1), y coordinate (-1 ≤ y ≤ 1) and the class ∈ {1,-1}.

# %% [markdown]
# ### Blue points first

# %%
# Install ipympl if it's not installed yet:
#!pip install ipympl

# %%
# %matplotlib widget
import matplotlib.pyplot as pl

fig = pl.figure(figsize=(6,6))
pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

dataset = []

def onclick_blue(event):
    global dataset
    if event.xdata is not None and event.ydata is not None:
        cx = event.xdata
        cy = event.ydata
        dataset.append((cx, cy, 1))
        pl.scatter(cx, cy, c='b', s=100, lw=0)
        pl.grid(True)
        pl.draw()

cid = fig.canvas.mpl_connect('button_press_event', onclick_blue)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.canvas.mpl_disconnect(cid)

# %% [markdown]
# ### Then, red points

# %%
# %matplotlib notebook

fig = pl.figure(figsize=(6,6))
for i in np.arange(len(dataset)):
    pl.scatter(dataset[i][0], dataset[i][1], c='b', s=100, lw=0)

pl.title("Input Dataset")
pl.xlim((-1.2,1.2))
pl.ylim((-1.2,1.2))

def onclick_red(event):
    global dataset
    cx = event.xdata
    cy = event.ydata
    dataset.append((cx, cy, -1))
    
    pl.scatter(cx, cy, c='r', s=100, lw=0)
    pl.grid(True)

fig.canvas.mpl_disconnect(onclick_blue)
cid = fig.canvas.mpl_connect('button_press_event', onclick_red)
# Out:
# <div id='4fb06b3e-39da-4041-b780-4c463dcf8b94'></div>

# %%
fig.canvas.mpl_disconnect(cid)

# %% [markdown]
# This is the dataset you just created. Check that there are no NaNs in the third column. Create once again the dataset if necessary

# %%
dataset
# Out:
# [(np.float64(-0.9522580645161288), np.float64(0.9402597402597404), 1),
#  (np.float64(-0.8077419354838709), np.float64(0.92987012987013), 1),
#  (np.float64(-0.6787096774193546), np.float64(0.9558441558441562), 1),
#  (np.float64(-0.5651612903225804), np.float64(0.92987012987013), 1),
#  (np.float64(-0.5187096774193547), np.float64(0.8623376623376626), 1),
#  (np.float64(-0.4877419354838708), np.float64(0.6545454545454548), 1),
#  (np.float64(-0.5393548387096772), np.float64(0.5194805194805197), 1),
#  (np.float64(-0.8645161290322579), np.float64(0.4311688311688313), 1),
#  (np.float64(-1.0141935483870967), np.float64(0.6597402597402597), 1),
#  (np.float64(-0.9058064516129031), np.float64(0.8000000000000003), 1),
#  (np.float64(-0.7199999999999999), np.float64(0.5194805194805197), 1),
#  (np.float64(-0.601290322580645), np.float64(0.5766233766233766), 1),
#  (np.float64(-0.6477419354838708), np.float64(0.7532467532467533), 1),
#  (np.float64(-0.745806451612903), np.float64(0.7844155844155845), 1),
#  (np.float64(-0.6683870967741934), np.float64(0.5766233766233766), 1),
#  (np.float64(-0.5135483870967741), np.float64(0.5194805194805197), 1),
#  (np.float64(-0.3380645161290321), np.float64(0.535064935064935), 1),
#  (np.float64(-0.7045161290322579), np.float64(0.316883116883117), 1),
#  (np.float64(-0.8851612903225805), np.float64(0.48311688311688306), 1),
#  (np.float64(-0.8541935483870966), np.float64(0.6285714285714286), 1),
#  (np.float64(0.56), np.float64(-0.5558441558441557), 1),
#  (np.float64(0.8077419354838713), np.float64(-0.5870129870129869), 1),
#  (np.float64(0.8696774193548387), np.float64(-0.5818181818181817), 1),
#  (np.float64(0.8696774193548387), np.float64(-0.48831168831168825), 1),
#  (np.float64(0.6270967741935487), np.float64(-0.2753246753246752), 1),
#  (np.float64(0.43096774193548404), np.float64(-0.27012987012987), 1),
#  (np.float64(0.3690322580645162), np.float64(-0.4207792207792207), 1),
#  (np.float64(0.49806451612903224), np.float64(-0.5714285714285713), 1),
#  (np.float64(0.7200000000000002), np.float64(-0.5298701298701298), 1),
#  (np.float64(0.854193548387097), np.float64(-0.6597402597402596), 1),
#  (np.float64(0.8438709677419358), np.float64(-0.8363636363636362), 1),
#  (np.float64(0.6064516129032258), np.float64(-1.0129870129870129), 1),
#  (np.float64(0.3793548387096777), np.float64(-0.8727272727272726), 1),
#  (np.float64(0.24516129032258083), np.float64(-0.6233766233766233), 1),
#  (np.float64(0.43096774193548404), np.float64(-0.6597402597402596), 1),
#  (np.float64(0.5238709677419355), np.float64(-0.7480519480519479), 1),
#  (np.float64(0.6683870967741936), np.float64(-0.7948051948051946), 1),
#  (np.float64(0.7458064516129035), np.float64(-0.7272727272727271), 1),
#  (np.float64(0.6477419354838712), np.float64(-0.5142857142857142), 1),
#  (np.float64(0.5703225806451613), np.float64(-0.4051948051948051), 1),
#  (np.float64(0.5290322580645164), np.float64(-0.3792207792207791), 1),
#  (np.float64(0.7045161290322581), np.float64(-0.3948051948051947), 1),
#  (np.float64(0.838709677419355), np.float64(-0.35844155844155834), 1),
#  (np.float64(0.910967741935484), np.float64(-0.3844155844155843), 1),
#  (np.float64(0.9470967741935485), np.float64(-0.5298701298701298), 1),
#  (np.float64(0.9212903225806452), np.float64(-0.7220779220779219), 1),
#  (np.float64(0.8748387096774195), np.float64(-0.9038961038961038), 1),
#  (np.float64(0.5703225806451613), np.float64(-0.696103896103896), 1),
#  (np.float64(0.5703225806451613), np.float64(-0.6597402597402596), 1),
#  (np.float64(0.709677419354839), np.float64(-0.6597402597402596), 1),
#  (np.float64(-0.5754838709677417), np.float64(0.8675324675324676), 1),
#  (np.float64(-0.42064516129032237), np.float64(0.7584415584415587), 1),
#  (np.float64(-0.7974193548387095), np.float64(0.6701298701298701), 1),
#  (np.float64(-0.6322580645161289), np.float64(0.4519480519480521), 1),
#  (np.float64(-0.776774193548387), np.float64(0.38961038961038974), 1),
#  (np.float64(-0.8954838709677417), np.float64(0.2961038961038962), 1),
#  (np.float64(-1.0038709677419353), np.float64(0.8467532467532468), 1),
#  (np.float64(-1.065806451612903), np.float64(0.7532467532467533), 1),
#  (np.float64(-1.0554838709677417), np.float64(0.5454545454545454), 1),
#  (np.float64(-0.5806451612903225), np.float64(0.6961038961038963), 1),
#  (np.float64(0.3793548387096777), np.float64(0.6789772727272729), -1),
#  (np.float64(0.34322580645161316), np.float64(0.7309253246753249), -1),
#  (np.float64(0.3845161290322583), np.float64(0.7828733766233769), -1),
#  (np.float64(0.6580645161290324), np.float64(0.8607954545454546), -1),
#  (np.float64(0.8025806451612905), np.float64(0.8556006493506496), -1),
#  (np.float64(0.8800000000000003), np.float64(0.7776785714285714), -1),
#  (np.float64(0.8645161290322583), np.float64(0.6010551948051948), -1),
#  (np.float64(0.7716129032258068), np.float64(0.4296266233766235), -1),
#  (np.float64(0.5445161290322584), np.float64(0.35170454545454555), -1),
#  (np.float64(0.3793548387096777), np.float64(0.4088474025974027), -1),
#  (np.float64(0.41032258064516136), np.float64(0.5491071428571428), -1),
#  (np.float64(0.5135483870967743), np.float64(0.4867694805194809), -1),
#  (np.float64(0.7045161290322581), np.float64(0.4088474025974027), -1),
#  (np.float64(0.7200000000000002), np.float64(0.6945616883116883), -1),
#  (np.float64(0.6064516129032258), np.float64(0.7361201298701299), -1),
#  (np.float64(0.5187096774193551), np.float64(0.6945616883116883), -1),
#  (np.float64(0.5341935483870968), np.float64(0.6478084415584417), -1),
#  (np.float64(0.5858064516129033), np.float64(0.6426136363636363), -1),
#  (np.float64(0.6580645161290324), np.float64(0.5698863636363636), -1),
#  (np.float64(0.7664516129032259), np.float64(0.5958603896103898), -1),
#  (np.float64(0.8593548387096774), np.float64(0.7153409090909091), -1),
#  (np.float64(0.838709677419355), np.float64(0.814042207792208), -1),
#  (np.float64(0.7716129032258068), np.float64(0.9231331168831169), -1),
#  (np.float64(0.5548387096774197), np.float64(0.9750811688311689), -1),
#  (np.float64(0.49290322580645185), np.float64(0.9543019480519481), -1),
#  (np.float64(0.41032258064516136), np.float64(0.9439123376623377), -1),
#  (np.float64(0.487741935483871), np.float64(0.8607954545454546), -1),
#  (np.float64(-0.5032258064516126), np.float64(-0.39634740259740253), -1),
#  (np.float64(-0.5032258064516126), np.float64(-0.37556818181818175), -1),
#  (np.float64(-0.5651612903225804), np.float64(-0.3184253246753246), -1),
#  (np.float64(-0.8025806451612901), np.float64(-0.24569805194805183), -1),
#  (np.float64(-0.8799999999999998), np.float64(-0.2924512987012986), -1),
#  (np.float64(-0.9264516129032256), np.float64(-0.34439935064935057), -1),
#  (np.float64(-0.9677419354838708), np.float64(-0.47946428571428545), -1),
#  (np.float64(-0.9677419354838708), np.float64(-0.7495941558441557), -1),
#  (np.float64(-0.9419354838709676), np.float64(-0.86387987012987), -1),
#  (np.float64(-0.7561290322580644), np.float64(-0.9262175324675324), -1),
#  (np.float64(-0.6167741935483869), np.float64(-0.8950487012987012), -1),
#  (np.float64(-0.3948387096774193), np.float64(-0.7236201298701297), -1),
#  (np.float64(-0.6993548387096773), np.float64(-0.5418019480519478), -1),
#  (np.float64(-0.7922580645161289), np.float64(-0.4067370129870129), -1),
#  (np.float64(-0.745806451612903), np.float64(-0.4327110389610389), -1),
#  (np.float64(-0.6064516129032257), np.float64(-0.4431006493506493), -1),
#  (np.float64(-0.5961290322580644), np.float64(-0.4638798701298701), -1),
#  (np.float64(-0.5341935483870965), np.float64(-0.5989448051948051), -1),
#  (np.float64(-0.544516129032258), np.float64(-0.6820616883116881), -1),
#  (np.float64(-0.6116129032258063), np.float64(-0.785957792207792), -1),
#  (np.float64(-0.7303225806451611), np.float64(-0.811931818181818), -1),
#  (np.float64(-0.7870967741935482), np.float64(-0.7651785714285713), -1),
#  (np.float64(-0.8232258064516127), np.float64(-0.6664772727272725), -1),
#  (np.float64(-0.8129032258064515), np.float64(-0.48985389610389585), -1),
#  (np.float64(-0.6941935483870966), np.float64(-0.6249188311688311), -1),
#  (np.float64(-0.6993548387096773), np.float64(-0.2560876623376622), -1),
#  (np.float64(-0.425806451612903), np.float64(-0.5418019480519478), -1),
#  (np.float64(-1.0296774193548386), np.float64(-0.5885551948051947), -1),
#  (np.float64(-0.5135483870967741), np.float64(-0.8275162337662336), -1),
#  (np.float64(-0.9161290322580643), np.float64(-0.5677759740259739), -1)]

# %% [markdown]
# ## Finding the weights by hand
# In this section you should try to find the set of weights that allows a Perceptron to separate the two classes you previously defined. Use the sliders to modify the value of each one of the connections and the bias of the Perceptron while trying to separate the two classes (blue and red). The curve on the right represents the classification error (MSE). If the modifications you provide improve the classification, you should see the error decreasing.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %%
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))

# %%
# %matplotlib inline
_= interact(plotter.plot_interactive, **plotter.controls)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Weight x:', max=2.0, min=-2.0, step=0.01), FloatSlid…
# <div id='68f213a9-706e-4612-aa0d-24e1a68f5e39'></div>

# %% [markdown]
# ## The Delta Rule
# In the following step we propose to solve the classification problem you defined by using the delta-rule algorithm. Look at the code in compute_delta_w and try to understand it.

# %% [raw]
#             ______________
#            /              \
# x __w_x__ j                l
#   _______ | f_act(I.W + b) |------ output
# y   w_y   l                j
#            \______________/
# Where:
# x = input x
# y = input y
# b = bias
# f_act = activation function
# I = vector of inputs
# W = vector of weights

# %% [markdown]
# $$ neta = (x * w\_x) + (y * w\_y) + b$$
# $$ output = f\_act(neta) $$
# $$ \Delta w\_x = \alpha * (target - output) * f\_act'(neta) * x $$
# $$ \Delta w\_y = \alpha * (target - output) * f\_act'(neta) * y $$
# $$ \Delta b = \alpha * (target - output) * f\_act'(neta) $$

# %%
def compute_delta_w(inputs, weights, bias, targets, alpha, activation_function):
    neta = np.dot(inputs, weights) + bias
    output, d_output = activation_function(neta)
    error = targets - output
    d_w_x = alpha * error * d_output * inputs[:,0]
    d_w_y = alpha * error * d_output * inputs[:,1]
    d_b = alpha * error * d_output
    return [d_w_x, d_w_y, d_b]

# %% [markdown]
# ## Batch learning
# When you launch the cell, the weights and the bias are initialized at random, and the algorithm perform some iterations (NUMBER_OF_EPOCHS) doing the following:
# +  for each point in the dataset, compute the modifications ( Δw ) to be done at each parameter in order to minimize the error function
# + sum up all the modifications -> batch policy
# + modify the weights and bias of the perceptron
#
# The cell records the effects of the modifications performed in a video. Therefore, you can visualize the learning process afterwards.

# %%
# %matplotlib inline

inputs = np.asarray(dataset)[:,0:2]
targets = np.asarray(dataset)[:,2]
weights = np.random.normal(size=2)
bias = np.random.normal(size=1)
activation_function = pt.htan

ALPHA = 0.1
NUMBER_OF_EPOCHS = 30

fig = pl.figure(figsize=(12, 4))
plotter = pt.PerceptronPlotter2D(data=np.asarray(dataset))
plotter.init_animation()

def run_epoch_batch(i, alpha, inputs, weights, bias, targets, activation_function):
    d_w_x, d_w_y, d_b = compute_delta_w(inputs, weights, bias, targets, ALPHA, activation_function)
    weights += np.array([np.sum(d_w_x), np.sum(d_w_y)])
    bias += np.sum(d_b)
    
    return plotter.data2animation(i, inputs, weights, bias, targets, activation_function)

SHOW_VIDEO = False       # change this flag if you are unable to see the video
if SHOW_VIDEO:
    anim = animation.FuncAnimation(fig, run_epoch_batch, fargs=(ALPHA, inputs, weights, bias, targets, activation_function), frames=NUMBER_OF_EPOCHS, interval=20, blit=True)
    pt.display_animation(anim)
else:
    for i in np.arange(NUMBER_OF_EPOCHS):
        run_epoch_batch(i, ALPHA, inputs, weights, bias, targets, activation_function)

# %% [markdown]
# ## Exercise
# You are free to modify the learning rate (ALPHA) and the number of iterations (NUMBER_OF_EPOCHS).
#
# Try different 2D classification problems and observe the behaviour of the algorithm in terms of:
# - Learning rate needed
# - Convergence speed
# - Oscillations
#
# Bare in mind that, in the current implementation, the parameters (weights and bias) are initialized randomly every time you launch the cell.
#
# Create dataset as shown and perform the following tests:
#
# 1. What happens if the boundaries between both classes are well defined?
# ![separable](separable.png)
#
# 2. What happens if the classes overlap? What could you say about oscillations in the error signal?
# ![overlapping](overlapping.png)
#
# 3. What happens if it is not possible to separate the classes with a single line? What could you say about local minima?
# ![non_separable](non_separable.png)
